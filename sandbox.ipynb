# %%
from Min3D.core.point_cloud_container import PointCloudContainer
from Min3D.core.geometry_container import GeometryContainer
from Min3D.core.mesh_container import MeshContainer
from Min3D.core.wireframe_container import WireframeContainer
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
container:PointCloudContainer
container = PointCloudContainer.from_ply("test_data/pcd_poisson.ply")

# %%
mesh:MeshContainer
mesh = MeshContainer.from_ply("test_data/watertight_mesh_from_alpha_shape.ply")

# %%
wireframe:WireframeContainer
wireframe = WireframeContainer.from_ply("test_data/lines_from_knn_search.ply")

# %%
wireframe.visualize_with(mesh)

# %%
mesh.get_min_bound(), mesh.get_max_bound()
# Out:
# (array([ 4.90909588e-06,  9.23318851e-07, -3.84521499e-08]),
#  array([5.30973603e-06, 1.28818237e-06, 2.50537113e-07]))

# %%
mesh.visualize()

# %%
import numpy as np
container.scale_axis(np.array([1,1,0.7]), inplace=True)

# %%
container.visualize()
